# %% [markdown]
# ### Classe do arquivo jogador.py
# - Está fucionando

# %%
from jogador import Jogador

um_jogador = Jogador("Guilherme")
dois_jogador = Jogador("Jão Gabriel")
tres_jogador = Jogador("Willian")

um_jogador.imprimir_quantidade_jogadores()
# Out:
# Neste momento, há 12 Jogadores conectados.

# %%
from documento import Documento

arquivo = Documento(23, 13, "lorem")

arquivo.__str__
# Out:
# <bound method Documento.__str__ of <documento.Documento object at 0x7fde7d1f7fe0>>

# %% [markdown]
# # 📚 Sistema de Controle de Biblioteca
# ## Planejamento Orientado a Objetos
#
# ---
#
# # 🎯 Objetivo
#
# Desenvolver um sistema em Python (console) para gerenciar:
#
# - Cadastro de livros
# - Cadastro de alunos
# - Empréstimos
# - Devoluções
# - Controle de atraso e multa
# - Relatórios
#
# ---
#
# # 🏛 Estrutura Geral do Sistema
#
# O sistema será composto por 4 classes principais:
#
# - Livro
# - Aluno
# - Emprestimo
# - Biblioteca
#
# A classe Biblioteca será responsável por gerenciar todo o sistema.
#
# ---
#
# # 📘 Classe: Livro
#
# ## 📌 Responsabilidade
# Representar um livro e controlar seu estado (disponível ou emprestado).
#
# ## 🔐 Atributos (privados)
#
# - _titulo
# - _autor
# - _ano_publicacao
# - _codigo
# - _disponivel (bool)
#
# ## ⚙️ Métodos
#
# - __init__(titulo, autor, ano_publicacao, codigo)
# - emprestar()
# - devolver()
# - esta_disponivel()
# - __str__()
#
# ---
#
# # 👤 Classe: Aluno
#
# ## 📌 Responsabilidade
# Representar um aluno e controlar seus livros emprestados.
#
# ## 🔐 Atributos (privados)
#
# - _nome
# - _matricula
# - _curso
# - _livros_emprestados (lista de objetos Livro)
#
# ## ⚙️ Métodos
#
# - __init__(nome, matricula, curso)
# - pegar_livro(livro)
# - devolver_livro(livro)
# - pode_emprestar()
# - listar_livros()
# - __str__()
#
# ## 📌 Regra de Negócio
#
# - Um aluno pode pegar no máximo 3 livros.
#
# ---
#
# # 📦 Classe: Emprestimo
#
# ## 📌 Responsabilidade
# Registrar e controlar um empréstimo específico.
#
# ## 🔐 Atributos (privados)
#
# - _aluno (objeto Aluno)
# - _livro (objeto Livro)
# - _data_emprestimo
# - _data_devolucao_prevista
# - _data_devolucao_real (inicialmente None)
#
# ## ⚙️ Métodos
#
# - __init__(aluno, livro)
# - registrar_devolucao()
# - esta_atrasado()
# - calcular_multa()
# - __str__()
#
# ## 📌 Regras
#
# - Prazo padrão: 7 dias
# - Multa: R$2 por dia de atraso
#
# ---
#
# # 🏛 Classe: Biblioteca
#
# ## 📌 Responsabilidade
# Gerenciar o sistema como um todo.
#
# ## 🔐 Atributos (privados)
#
# - _livros (lista de Livro)
# - _alunos (lista de Aluno)
# - _emprestimos (lista de Emprestimo)
#
# ---
#
# ## ⚙️ Métodos
#
# ### 📚 Cadastro
#
# - cadastrar_livro(livro)
# - cadastrar_aluno(aluno)
#
# ---
#
# ### 🔍 Busca
#
# - buscar_livro_por_codigo(codigo)
# - buscar_aluno_por_matricula(matricula)
#
# ---
#
# ### 📦 Empréstimo
#
# - realizar_emprestimo(codigo_livro, matricula_aluno)
#
# Fluxo:
# 1. Verificar se livro existe
# 2. Verificar se aluno existe
# 3. Verificar se livro está disponível
# 4. Verificar se aluno pode pegar
# 5. Criar objeto Emprestimo
# 6. Atualizar status do livro
# 7. Atualizar lista do aluno
# 8. Salvar empréstimo na biblioteca
#
# ---
#
# ### 🔄 Devolução
#
# - realizar_devolucao(codigo_livro, matricula_aluno)
#
# Fluxo:
# 1. Localizar empréstimo ativo
# 2. Registrar devolução
# 3. Atualizar livro para disponível
# 4. Remover livro do aluno
# 5. Verificar atraso
# 6. Calcular multa se necessário
#
# ---
#
# ### 📊 Relatórios
#
# - listar_livros_disponiveis()
# - listar_livros_emprestados()
# - listar_alunos()
# - listar_emprestimos()
# - listar_inadimplentes()
#
# ---
#
# # 🧠 Conceitos de POO Aplicados
#
# - Encapsulamento
# - Composição
# - Associação entre objetos
# - Regras de negócio dentro das classes
# - Controle de estado
# - Manipulação de listas de objetos
#
# ---
#
# # 🏗 Organização Recomendada
#
# ## Estrutura Simples
#
# main.py
#
# ## Estrutura Organizada
#
# models/
#     livro.py
#     aluno.py
#     emprestimo.py
#
# biblioteca.py
# main.py
#
# ---
#
# # ✅ Perguntas para validar sua lógica
#
# 1. Quem deve alterar o status do livro?
# 2. Quem cria o objeto Emprestimo?
# 3. Onde fica a regra dos 3 livros?
# 4. Onde fica a regra da multa?
# 5. A Biblioteca deve acessar atributos diretamente ou usar métodos?
#
# Se você souber responder isso antes de codar,
# sua modelagem está bem estruturada.
